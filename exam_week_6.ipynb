# %%
import pandas as pd
import numpy as np

url = r'C:\Users\VSPC\Documents\GitHub\exam_ironhack_week_6_eda\Melbourne_housing_FULL.csv'

melbourne_housin_raw = pd.read_csv(url)

# %%
melbourne_housin_raw.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 5  Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# 6  Abbotsford         55a Park St      4    h  1600000.0     VB   Nelson
# 7  Abbotsford        16 Maugie St      4    h        NaN     SN   Nelson
# 8  Abbotsford        53 Turner St      2    h        NaN      S   Biggin
# 9  Abbotsford        99 Turner St      2    h        NaN      S  Collins
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# ...

# %% [markdown]
# ### Question 1

# %%
melbourne_housin_raw.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
melbourne_housin_raw['Price'] = melbourne_housin_raw['Price'].astype('Int64')

melbourne_housin_raw['Price']
# Out:
# 0           <NA>
# 1        1480000
# 2        1035000
# 3           <NA>
# 4        1465000
#           ...
# 34852    1480000
# 34853     888000
# 34854     705000
# 34855    1140000
# 34856    1020000
# Name: Price, Length: 34857, dtype: Int64

# %%
melbourne_housin_raw.shape
# Out:
# (34857, 21)

# %%
melbourne_housin_nonan_price = melbourne_housin_raw.dropna(subset=['Price'])

melbourne_housin_nonan_price.shape
# Out:
# (27247, 21)

# %%
rows_raw = melbourne_housin_raw.shape[0]

rows_price = melbourne_housin_nonan_price.shape[0]

percentage_of_drop =  rows_price / rows_raw * 100

print(f'The percentage of the total after dropna is: {percentage_of_drop}')
# Out:
# The percentage of the total after dropna is: 78.16794331124308

# %% [markdown]
# ### Question 2

# %%
melbourne_housin_raw['Type'].value_counts()
# Out:
# Type
# h    23980
# u     7297
# t     3580
# Name: count, dtype: int64

# %%
mode_type = melbourne_housin_raw['Type'].mode()[0]

percentage_mode = ( melbourne_housin_raw['Type'] == mode_type).mean() * 100

print(f'The percentage of the most common value is: {percentage_mode}')
# Out:
# The percentage of the most common value is: 68.79536391542588

# %% [markdown]
# ### Question 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

type_properties = melbourne_housin_raw['Type'].value_counts()


plt.figure(figsize=(10, 6))
type_properties.plot(kind='bar', color='skyblue')
plt.title('Distribution of Property Types')
plt.xlabel('Property Type')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Question 4

# %%
melbourne_housin_raw.head(3)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford    68 Studley St      2    h     <NA>     SS  Jellis  3/09/2016
# 1  Abbotsford     85 Turner St      2    h  1480000      S  Biggin  3/12/2016
# 2  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin  4/02/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     126.0           NaN        NaN
# 1       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
# 2       2.5    3067.0  ...       1.0  0.0     156.0          79.0     1900.0
#
#           CouncilArea Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# ...

# %%
price_rooms_relationship = melbourne_housin_raw[['Price', 'Rooms']]

price_rooms_relationship.dropna()
# Out:
#          Price  Rooms
# 1      1480000      2
# 2      1035000      2
# 4      1465000      3
# 5       850000      3
# 6      1600000      4
# ...        ...    ...
# 34852  1480000      4
# 34853   888000      2
# 34854   705000      2
# 34855  1140000      3
# 34856  1020000      2
#
# [27247 rows x 2 columns]

# %%
avg_price_per_room = price_rooms_relationship.groupby('Rooms')['Price'].mean()

avg_price_per_room.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Average Price per Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Question 5

# %%
from scipy.stats import spearmanr

price_rooms_relationship = melbourne_housin_raw[['Price', 'Rooms']].dropna()

spearman_corr, p_value = spearmanr(price_rooms_relationship['Price'], price_rooms_relationship['Rooms'])

print(f"Spearman correlation coefficient: {spearman_corr:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Spearman correlation coefficient: 0.50
# P-value: 0.0000

# %% [markdown]
# ### Question 6

# %%
melbourne_housin_raw.head(3)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford    68 Studley St      2    h     <NA>     SS  Jellis  3/09/2016
# 1  Abbotsford     85 Turner St      2    h  1480000      S  Biggin  3/12/2016
# 2  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin  4/02/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     126.0           NaN        NaN
# 1       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
# 2       2.5    3067.0  ...       1.0  0.0     156.0          79.0     1900.0
#
#           CouncilArea Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# ...

# %%
filter_distance_from_cbd = melbourne_housin_raw[['Distance', 'Price']].dropna()

spearman_corr, p_value = spearmanr(filter_distance_from_cbd['Distance'], filter_distance_from_cbd['Price'])

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Distance', y='Price', data=filter_distance_from_cbd, alpha=0.5, color='blue')
plt.title(f'Relationship between Distance from CBD and Price\n(Spearman correlation = {spearman_corr:.2f})')
plt.xlabel('Distance from CBD (km)')
plt.ylabel('Price (AUD)')
plt.show()


spearman_corr, p_value
# Out:
# (-0.18809341092744206, 2.0693054050425284e-215)

# %% [markdown]
# ### Question 7

# %%
price_property_size_relationship = melbourne_housin_raw[['BuildingArea', 'Price']].dropna()

spearman_corr, p_value = spearmanr(price_property_size_relationship['BuildingArea'], price_property_size_relationship['Price'])

spearman_corr, p_value
# Out:
# (0.5553540450665009, 0.0)

# %% [markdown]
# ### Question 8

# %%
land_price_relationship = melbourne_housin_raw[['Landsize', 'Price']].dropna()

land_price_relationship['Landsize_cat'] = pd.qcut(land_price_relationship['Landsize'], q=7, labels=[f'Quantile {i+1}' for i in range(7)])

med_price_land_cat = land_price_relationship.groupby('Landsize_cat')['Price'].median().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Landsize_cat', y='Price', data=med_price_land_cat, palette='viridis')
plt.title('Median Property Price by Land Size Category (q=7)')
plt.xlabel('Land Size Category')
plt.ylabel('Median Price (AUD)')
plt.show()
# Out:
# C:\Users\VSPC\AppData\Local\Temp\ipykernel_17848\4011904109.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   med_price_land_cat = land_price_relationship.groupby('Landsize_cat')['Price'].median().reset_index()
# C:\Users\VSPC\AppData\Local\Temp\ipykernel_17848\4011904109.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Landsize_cat', y='Price', data=med_price_land_cat, palette='viridis')

# %% [markdown]
# ### Question 9

# %%
price = melbourne_housin_raw[['Price']].dropna()

plt.figure(figsize=(8, 5))
sns.boxplot(x=price['Price'], color='skyblue')
plt.title('Boxplot of Property Prices')
plt.xlabel('Price (AUD)')
plt.show()

# %%
Q1 = price['Price'].quantile(0.25)
Q3 = price['Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

non_outliers = price[(price['Price'] >= lower_bound) & (price['Price'] <= upper_bound)]

percentage_outliers = (len(price) - len(non_outliers)) / len(price) * 100

percentage_outliers
# Out:
# 4.690424633904651

# %% [markdown]
# ### Question 10

# %%
import scipy.stats as stats

price_skewness = price['Price'].skew()
price_kurtosis = price['Price'].kurtosis()

plt.figure(figsize=(8, 6))
stats.probplot(price['Price'], dist="norm", plot=plt)
plt.title(f'QQ Plot of Property Prices\n(Skewness: {price_skewness:.2f}, Kurtosis: {price_kurtosis:.2f})')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid()
plt.show()

price_skewness, price_kurtosis
# Out:
# (2.5889693410528594, 13.097200515556374)

# %% [markdown]
# ### Question 11

# %%
from scipy.stats import kstest

price_values = price['Price'].dropna()

ks_statistic, p_value = kstest(price_values, 'norm', args=(price_values.mean(), price_values.std()))

ks_statistic, p_value
# Out:
# (0.1375128495378416, 0.0)

# %% [markdown]
# ### Question 12

# %%
price_type_relationship = melbourne_housin_raw[['Price', 'Type']].dropna()


plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Price', data=price_type_relationship, palette='viridis')
plt.title('Property Prices by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Price (AUD)')
plt.show()
# Out:
# C:\Users\VSPC\AppData\Local\Temp\ipykernel_17848\3410185356.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Type', y='Price', data=price_type_relationship, palette='viridis')

# %% [markdown]
# ### Question 13

# %%
region_price_relationship = melbourne_housin_raw[['Price', 'Regionname']].dropna()

median_price_by_region = region_price_relationship.groupby('Regionname')['Price'].median().reset_index()

most_expensive = median_price_by_region.loc[median_price_by_region['Price'].idxmax(), 'Regionname']
cheapest = median_price_by_region.loc[median_price_by_region['Price'].idxmin(), 'Regionname']

most_expensive, cheapest
# Out:
# ('Southern Metropolitan', 'Western Victoria')

# %% [markdown]
# ### Question 14

# %%
from scipy.stats import chi2_contingency

region_price_relationship['Price_Category'] = pd.cut(region_price_relationship['Price'], bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

contingency_table = pd.crosstab(region_price_relationship['Regionname'], region_price_relationship['Price_Category'])

chi2, p, dof, expected = chi2_contingency(contingency_table)

n = np.sum(contingency_table.values)
cramers_v = np.sqrt(chi2 / (n * min(contingency_table.shape) - 1))

chi2, p, cramers_v
# Out:
# (1564.7349988019678, 0.0, 0.107176989620049)

# %% [markdown]
# ### Question 15

# %%
melbourne_housin_raw['Date'] = pd.to_datetime(melbourne_housin_raw['Date'], format="%d/%m/%Y")

melbourne_housin_raw['Year'] = melbourne_housin_raw['Date'].dt.year

earliest_year = melbourne_housin_raw['Year'].min()
latest_year = melbourne_housin_raw['Year'].max()

median_price_earliest = melbourne_housin_raw[melbourne_housin_raw['Year'] == earliest_year]['Price'].median()
median_price_latest = melbourne_housin_raw[melbourne_housin_raw['Year'] == latest_year]['Price'].median()

percentage_change = ((median_price_latest - median_price_earliest) / median_price_earliest) * 100

earliest_year, latest_year, median_price_earliest, median_price_latest, percentage_change
# Out:
# (2016, 2018, 885000.0, 836500.0, -5.480225988700565)

# %% [markdown]
# ### Question 16

# %%
melbourne_housin_raw['Month'] = melbourne_housin_raw['Date'].dt.month_name()

monthly_sales = melbourne_housin_raw['Month'].value_counts()

most_sales_month = monthly_sales.idxmax()
most_sales_count = monthly_sales.max()

most_sales_month, most_sales_count
# Out:
# ('November', 4387)

# %% [markdown]
# Finished!
